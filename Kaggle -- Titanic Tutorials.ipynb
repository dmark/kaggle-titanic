# %%
import csv as csv
import numpy as np

csv_file_object = csv.reader(open('data/train.csv', 'rb'))
header = csv_file_object.next()
data = []

for row in csv_file_object:
    data.append(row)
data = np.array(data)
data
# Out:
# array([['1', '0', '3', ..., '7.25', '', 'S'],
#        ['2', '1', '1', ..., '71.2833', 'C85', 'C'],
#        ['3', '1', '3', ..., '7.925', '', 'S'],
#        ...,
#        ['889', '0', '3', ..., '23.45', '', 'S'],
#        ['890', '1', '1', ..., '30', 'C148', 'C'],
#        ['891', '0', '3', ..., '7.75', '', 'Q']],
#       dtype='|S82')

# %%
data[0:15,5]
# Out:
# array(['22', '38', '26', '35', '35', '', '54', '2', '27', '14', '4', '58',
#        '20', '39', '14'],
#       dtype='|S82')

# %%
type(data[0::,5])
# Out:
# numpy.ndarray

# %%
ages_onboard = data[0::,5].astype(np.float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-c15380fd29f0> in <module>()
# ----> 1 ages_onboard = data[0::,5].astype(np.float)
#
# ValueError: could not convert string to float:

# %%
import pandas as pd

df = pd.read_csv('data/train.csv', header=0)

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['Age'][0:10]
# Out:
# 0    22
# 1    38
# 2    26
# 3    35
# 4    35
# 5   NaN
# 6    54
# 7     2
# 8    27
# 9    14
# Name: Age, dtype: float64

# %%
df.Age[0:10]
# Out:
# 0    22
# 1    38
# 2    26
# 3    35
# 4    35
# 5   NaN
# 6    54
# 7     2
# 8    27
# 9    14
# Name: Age, dtype: float64

# %%
df['Cabin'][0:10]
# Out:
# 0     NaN
# 1     C85
# 2     NaN
# 3    C123
# 4     NaN
# 5     NaN
# 6     E46
# 7     NaN
# 8     NaN
# 9     NaN
# Name: Cabin, dtype: object

# %%
type(df['Age'])
# Out:
# pandas.core.series.Series

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['Age'].median()
# Out:
# 28.0

# %%
df[['Sex', 'Pclass', 'Age']][0:5]
# Out:
#       Sex  Pclass  Age
# 0    male       3   22
# 1  female       1   38
# 2  female       3   26
# 3  female       1   35
# 4    male       3   35

# %%
df[df['Age'] > 60][['Sex','Pclass','Age','Survived']]
# Out:
#         Sex  Pclass   Age  Survived
# 33     male       2  66.0         0
# 54     male       1  65.0         0
# 96     male       1  71.0         0
# 116    male       3  70.5         0
# 170    male       1  61.0         0
# 252    male       1  62.0         0
# 275  female       1  63.0         1
# 280    male       3  65.0         0
# 326    male       3  61.0         0
# 438    male       1  64.0         0
# 456    male       1  65.0         0
# 483  female       3  63.0         1
# 493    male       1  71.0         0
# 545    male       1  64.0         0
# 555    male       1  62.0         0
# 570    male       2  62.0         1
# 625    male       1  61.0         0
# 630    male       1  80.0         1
# 672    male       2  70.0         0
# 745    male       1  70.0         0
# 829  female       1  62.0         1
# 851    male       3  74.0         0

# %%
df[df['Age'].isnull()][['Sex','Pclass','Age']]
# Out:
#         Sex  Pclass  Age
# 5      male       3  NaN
# 17     male       2  NaN
# 19   female       3  NaN
# 26     male       3  NaN
# 28   female       3  NaN
# 29     male       3  NaN
# 31   female       1  NaN
# 32   female       3  NaN
# 36     male       3  NaN
# 42     male       3  NaN
# 45     male       3  NaN
# 46     male       3  NaN
# 47   female       3  NaN
# 48     male       3  NaN
# 55     male       1  NaN
# 64     male       1  NaN
# 65     male       3  NaN
# 76     male       3  NaN
# 77     male       3  NaN
# 82   female       3  NaN
# 87     male       3  NaN
# 95     male       3  NaN
# 101    male       3  NaN
# 107    male       3  NaN
# 109  female       3  NaN
# 121    male       3  NaN
# 126    male       3  NaN
# 128  female       3  NaN
# 140  female       3  NaN
# 154    male       3  NaN
# ..      ...     ...  ...
# 718    male       3  NaN
# 727  female       3  NaN
# 732    male       2  NaN
# 738    male       3  NaN
# 739    male       3  NaN
# 740    male       1  NaN
# 760    male       3  NaN
# 766    male       1  NaN
# 768    male       3  NaN
# 773    male       3  NaN
# 776    male       3  NaN
# 778    male       3  NaN
# 783    male       3  NaN
# 790    male       3  NaN
# 792  female       3  NaN
# 793    male       1  NaN
# 815    male       1  NaN
# 825    male       3  NaN
# 826    male       3  NaN
# 828    male       3  NaN
# 832    male       3  NaN
# 837    male       3  NaN
# 839    male       1  NaN
# 846    male       3  NaN
# 849  female       1  NaN
# 859    male       3  NaN
# 863  female       3  NaN
# 868    male       3  NaN
# 878    male       3  NaN
# 888  female       3  NaN
#
# [177 rows x 3 columns]

# %%
for i in range(1,4):
    print i, len(df[ (df['Sex'] == 'male') & (df['Pclass'] == i) ])
# Out:
# 1 122
# 2 108
# 3 347

# %%
import pylab as P
df['Age'].hist()
P.show()

# %%
df['Age'].dropna().hist(bins=16, range=(0,80), alpha=0.5)
P.show()

# %%
df['Gender'] = 4

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender
# 0      0         A/5 21171   7.2500   NaN        S       4
# 1      0          PC 17599  71.2833   C85        C       4
# 2      0  STON/O2. 3101282   7.9250   NaN        S       4
# 3      0            113803  53.1000  C123        S       4
# 4      0            373450   8.0500   NaN        S       4

# %%
df['Gender'] = df['Sex'].map( lambda x: x[0].upper() )

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked Gender
# 0      0         A/5 21171   7.2500   NaN        S      M
# 1      0          PC 17599  71.2833   C85        C      F
# 2      0  STON/O2. 3101282   7.9250   NaN        S      F
# 3      0            113803  53.1000  C123        S      F
# 4      0            373450   8.0500   NaN        S      M

# %%
df['Gender'] = df['Sex'].map( {'female':0, 'male':1} ).astype(int)

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender
# 0      0         A/5 21171   7.2500   NaN        S       1
# 1      0          PC 17599  71.2833   C85        C       0
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0
# 3      0            113803  53.1000  C123        S       0
# 4      0            373450   8.0500   NaN        S       1

# %%
df['Port_of_Origin'] = df['Embarked'].map( { None: 0, 'S': 1, 'C': 2, 'Q': 3} ).astype(int)

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender  Port_of_Origin
# 0      0         A/5 21171   7.2500   NaN        S       1               1
# 1      0          PC 17599  71.2833   C85        C       0               2
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0               1
# 3      0            113803  53.1000  C123        S       0               1
# 4      0            373450   8.0500   NaN        S       1               1

# %%
df[ df['Port_of_Origin'] == 0 ]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex  Age  SibSp  Parch  Ticket  Fare Cabin Embarked  Gender  \
# 61   female   38      0      0  113572    80   B28      NaN       0
# 829  female   62      0      0  113572    80   B28      NaN       0
#
#      Port_of_Origin
# 61                0
# 829               0

# %%
median_ages = np.zeros((2,3))
median_ages
# Out:
# array([[ 0.,  0.,  0.],
#        [ 0.,  0.,  0.]])

# %%
for i in range(0,2):
    for j in range(0,3):
        median_ages[i,j] = df[(df['Gender'] == i) & 
                              (df['Pclass'] == j+1)]['Age'].dropna().median()

# %%
median_ages
# Out:
# array([[ 35. ,  28. ,  21.5],
#        [ 40. ,  30. ,  25. ]])

# %%
df['AgeFill'] = df['Age']
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender  Port_of_Origin  \
# 0      0         A/5 21171   7.2500   NaN        S       1               1
# 1      0          PC 17599  71.2833   C85        C       0               2
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0               1
# 3      0            113803  53.1000  C123        S       0               1
# 4      0            373450   8.0500   NaN        S       1               1
#
#    AgeFill
# 0       22
# 1       38
# 2       26
# 3       35
# 4       35

# %%
df[ df['Age'].isnull() ][['Gender', 'Pclass', 'Age', 'AgeFill']].head(10)
# Out:
#     Gender  Pclass  Age  AgeFill
# 5        1       3  NaN      NaN
# 17       1       2  NaN      NaN
# 19       0       3  NaN      NaN
# 26       1       3  NaN      NaN
# 28       0       3  NaN      NaN
# 29       1       3  NaN      NaN
# 31       0       1  NaN      NaN
# 32       0       3  NaN      NaN
# 36       1       3  NaN      NaN
# 42       1       3  NaN      NaN

# %%
for i in range(0,2):
    for j in range(0,3):
        df.loc[ (df.Age.isnull()) & (df.Gender == i) & (df.Pclass == j+1),
               'AgeFill'] = median_ages[i,j]

# %%
df[ df['Age'].isnull() ][['Gender', 'Pclass', 'Age', 'AgeFill']].head(10)
# Out:
#     Gender  Pclass  Age  AgeFill
# 5        1       3  NaN     25.0
# 17       1       2  NaN     30.0
# 19       0       3  NaN     21.5
# 26       1       3  NaN     25.0
# 28       0       3  NaN     21.5
# 29       1       3  NaN     25.0
# 31       0       1  NaN     35.0
# 32       0       3  NaN     21.5
# 36       1       3  NaN     25.0
# 42       1       3  NaN     25.0

# %%
df['AgeIsNull'] = pd.isnull(df.Age).astype(int)
df[ df['Age'].isnull() ][['Gender', 'Pclass', 'Age', 'AgeFill', 'AgeIsNull']].head(10)
# Out:
#     Gender  Pclass  Age  AgeFill  AgeIsNull
# 5        1       3  NaN     25.0          1
# 17       1       2  NaN     30.0          1
# 19       0       3  NaN     21.5          1
# 26       1       3  NaN     25.0          1
# 28       0       3  NaN     21.5          1
# 29       1       3  NaN     25.0          1
# 31       0       1  NaN     35.0          1
# 32       0       3  NaN     21.5          1
# 36       1       3  NaN     25.0          1
# 42       1       3  NaN     25.0          1

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare      Gender  Port_of_Origin     AgeFill  \
# count  891.000000  891.000000  891.000000      891.000000  891.000000
# mean     0.381594   32.204208    0.647587        1.359147   29.112424
# std      0.806057   49.693429    0.477990        0.638707   13.304424
# min      0.000000    0.000000    0.000000        0.000000    0.420000
# 25%      0.000000    7.910400    0.000000        1.000000   21.500000
# 50%      0.000000   14.454200    1.000000        1.000000   26.000000
# 75%      0.000000   31.000000    1.000000        2.000000   36.000000
# max      6.000000  512.329200    1.000000        3.000000   80.000000
#
#         AgeIsNull
# count  891.000000
# mean     0.198653
# std      0.399210
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max      1.000000

# %%
df['FamilySize'] = df['SibSp'] + df['Parch']
df['Age*Class'] = df.AgeFill * df.Pclass
df['Age*Class'].hist()
P.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 18 columns):
# PassengerId       891 non-null int64
# Survived          891 non-null int64
# Pclass            891 non-null int64
# Name              891 non-null object
# Sex               891 non-null object
# Age               714 non-null float64
# SibSp             891 non-null int64
# Parch             891 non-null int64
# Ticket            891 non-null object
# Fare              891 non-null float64
# Cabin             204 non-null object
# Embarked          889 non-null object
# Gender            891 non-null int64
# Port_of_Origin    891 non-null int64
# AgeFill           891 non-null float64
# AgeIsNull         891 non-null int64
# FamilySize        891 non-null int64
# Age*Class         891 non-null float64
# dtypes: float64(4), int64(9), object(5)

# %%
df.dtypes[df.dtypes.map(lambda x: x=='object')]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df = df.drop(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], axis=1)
df = df.drop(['Age'], axis=1)

# %%
df = df.dropna()

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch     Fare  Gender  \
# 0            1         0       3      1      0   7.2500       1
# 1            2         1       1      1      0  71.2833       0
# 2            3         1       3      0      0   7.9250       0
# 3            4         1       1      1      0  53.1000       0
# 4            5         0       3      0      0   8.0500       1
# 5            6         0       3      0      0   8.4583       1
# 6            7         0       1      0      0  51.8625       1
# 7            8         0       3      3      1  21.0750       1
# 8            9         1       3      0      2  11.1333       0
# 9           10         1       2      1      0  30.0708       0
#
#    Port_of_Origin  AgeFill  AgeIsNull  FamilySize  Age*Class
# 0               1       22          0           1         66
# 1               2       38          0           1         38
# 2               1       26          0           0         78
# 3               1       35          0           1         35
# 4               1       35          0           0        105
# 5               3       25          1           0         75
# 6               1       54          0           0         54
# 7               1        2          0           4          6
# 8               1       27          0           2         81
# 9               2       14          0           1         28

# %%
train_data = df.values
train_data
# Out:
# array([[   1. ,    0. ,    3. , ...,    0. ,    1. ,   66. ],
#        [   2. ,    1. ,    1. , ...,    0. ,    1. ,   38. ],
#        [   3. ,    1. ,    3. , ...,    0. ,    0. ,   78. ],
#        ...,
#        [ 889. ,    0. ,    3. , ...,    1. ,    3. ,   64.5],
#        [ 890. ,    1. ,    1. , ...,    0. ,    0. ,   26. ],
#        [ 891. ,    0. ,    3. , ...,    0. ,    0. ,   96. ]])

# %%
data
# Out:
# array([['1', '0', '3', ..., '7.25', '', 'S'],
#        ['2', '1', '1', ..., '71.2833', 'C85', 'C'],
#        ['3', '1', '3', ..., '7.925', '', 'S'],
#        ...,
#        ['889', '0', '3', ..., '23.45', '', 'S'],
#        ['890', '1', '1', ..., '30', 'C148', 'C'],
#        ['891', '0', '3', ..., '7.75', '', 'Q']],
#       dtype='|S82')

# %%
test_df = pd.read_csv('data/test.csv', header=0)
test_df['Gender'] = test_df['Sex'].map( {'female': 0, 'male': 1} ).astype(int)
test_df['Port_of_Origin'] = df['Embarked'].map( { None: 0, 'S': 1, 'C': 2, 'Q': 3} ).astype(int)
median_age = test_df['Age'].dropna().median()
if len(test_df.Age[ test_df.Age.isnull() ]) > 0:
    test_df.loc[ (test_df.Age.isnull()), 'Age'] = median_age
if len(test_df.Fare[ test_df.Fare.isnull() ]) > 0:
    median_fare = np.zeros(3)
    for f in range(0,3):                                              # loop 0 to 2
        median_fare[f] = test_df[ test_df.Pclass == f+1 ]['Fare'].dropna().median()
    for f in range(0,3):                                              # loop 0 to 2
        test_df.loc[ (test_df.Fare.isnull()) & (test_df.Pclass == f+1 ), 'Fare'] = median_fare[f]
ids = test_df['PassengerId'].values
test_df = test_df.drop(['Name', 'Sex', 'Ticket', 'Cabin', 'PassengerId'], axis=1)

test_data = test_df.values()

from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators = 100)
forest = forest.fit(train_data[0::,1::],train_data[0::,0])
output = forest.predict(test_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-e658f48cb8b7> in <module>()
#       1 test_df = pd.read_csv('data/test.csv', header=0)
#       2 test_df['Gender'] = test_df['Sex'].map( {'female': 0, 'male': 1} ).astype(int)
# ----> 3 test_df['Port_of_Origin'] = df['Embarked'].map( { None: 0, 'S': 1, 'C': 2, 'Q': 3} ).astype(int)
#       4 median_age = test_df['Age'].dropna().median()
#       5 if len(test_df.Age[ test_df.Age.isnull() ]) > 0:
#
# /home/citmkd/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1682             return self._getitem_multilevel(key)
#    1683         else:
# -> 1684             return self._getitem_column(key)
#    1685
#    1686     def _getitem_column(self, key):
#
# /home/citmkd/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1689         # get column
#    1690         if self.columns.is_unique:
# -> 1691             return self._get_item_cache(key)
#    1692
#    1693         # duplicate columns & possible reduce dimensionaility
#
# /home/citmkd/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1050         res = cache.get(item)
#    1051         if res is None:
# -> 1052             values = self._data.get(item)
#    1053             res = self._box_item_values(item, values)
#    1054             cache[item] = res
#
# /home/citmkd/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item)
#    2535
#    2536             if not isnull(item):
# -> 2537                 loc = self.items.get_loc(item)
#    2538             else:
#    2539                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /home/citmkd/anaconda/lib/python2.7/site-packages/pandas/core/index.pyc in get_loc(self, key)
#    1154         loc : int if unique index, possibly slice or mask if not
#    1155         """
# -> 1156         return self._engine.get_loc(_values_from_object(key))
#    1157
#    1158     def get_value(self, series, key):
#
# /home/citmkd/anaconda/lib/python2.7/site-packages/pandas/index.so in pandas.index.IndexEngine.get_loc (pandas/index.c:3650)()
#
# /home/citmkd/anaconda/lib/python2.7/site-packages/pandas/index.so in pandas.index.IndexEngine.get_loc (pandas/index.c:3528)()
#
# /home/citmkd/anaconda/lib/python2.7/site-packages/pandas/hashtable.so in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:11908)()
#
# /home/citmkd/anaconda/lib/python2.7/site-packages/pandas/hashtable.so in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:11861)()
#
# KeyError: 'Embarked'
